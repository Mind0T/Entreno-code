# %%
import pandas as pd
datos=pd.read_csv("fahrenheit.csv")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fahrenheit  10 non-null     int64
#  1   Celsius     10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 288.0 bytes

# %%
datos.head()
# Out:
#    Fahrenheit  Celsius
# 0           0    -17.8
# 1          10    -12.2
# 2          20     -6.7
# 3          32      0.0
# 4          50     10.0

# %%
import seaborn as sb
sb.scatterplot(x="Fahrenheit",y="Celsius",data=datos,hue="Celsius",palette="coolwarm")
# Out:
# <Axes: xlabel='Fahrenheit', ylabel='Celsius'>

# %%
x=datos["Fahrenheit"]
y=datos["Celsius"]

# %%
x.values
# Out:
# array([  0,  10,  20,  32,  50,  68,  77,  86,  95, 104], dtype=int64)

# %%
y.values
# Out:
# array([-17.8, -12.2,  -6.7,   0. ,  10. ,  20. ,  25. ,  30. ,  35. ,
#         40. ])

# %%
x_procesada=x.values.reshape(-1,1)
y_procesada=y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo=LinearRegression()

# %%
modelo.fit(x_procesada,y_procesada)
# Out:
# LinearRegression()

# %%
fahrenheit=95
prediccion=modelo.predict([[fahrenheit]])
print(prediccion)
# Out:
# [[35.00113527]]

# %%
modelo.score(x_procesada,y_procesada)
# Out:
# 0.9999995212700372
