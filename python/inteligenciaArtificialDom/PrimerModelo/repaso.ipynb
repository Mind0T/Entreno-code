# %%
import pandas as pd
base=pd.read_csv("fa_to_kel.csv")
base
# Out:
#     fahrenheit  kelvin
# 0         14.0  263.15
# 1         17.6  265.15
# 2         21.2  267.15
# 3         24.8  269.15
# 4         28.4  271.15
# 5         32.0  273.15
# 6         35.6  275.15
# 7         39.2  277.15
# 8         42.8  279.15
# 9         46.4  281.15
# 10        50.0  283.15
# 11        53.6  285.15
# 12        57.2  287.15
# 13        60.8  289.15
# 14        64.4  291.15
# 15        68.0  293.15
# 16        71.6  295.15
# 17        75.2  297.15
# 18        78.8  299.15
# 19        82.4  301.15

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fahrenheit  20 non-null     float64
#  1   kelvin      20 non-null     float64
# dtypes: float64(2)
# memory usage: 448.0 bytes

# %%
base.head(10)
# Out:
#    fahrenheit  kelvin
# 0        14.0  263.15
# 1        17.6  265.15
# 2        21.2  267.15
# 3        24.8  269.15
# 4        28.4  271.15
# 5        32.0  273.15
# 6        35.6  275.15
# 7        39.2  277.15
# 8        42.8  279.15
# 9        46.4  281.15

# %%
import seaborn as sb

# %%
sb.scatterplot(x="fahrenheit",y="kelvin",data=base,hue="fahrenheit",palette="coolwarm")
# Out:
# <Axes: xlabel='fahrenheit', ylabel='kelvin'>

# %%
x=base["fahrenheit"]
y=base["kelvin"]
x
# Out:
# 0     14.0
# 1     17.6
# 2     21.2
# 3     24.8
# 4     28.4
# 5     32.0
# 6     35.6
# 7     39.2
# 8     42.8
# 9     46.4
# 10    50.0
# 11    53.6
# 12    57.2
# 13    60.8
# 14    64.4
# 15    68.0
# 16    71.6
# 17    75.2
# 18    78.8
# 19    82.4
# Name: fahrenheit, dtype: float64

# %%
x_procesada=x.values.reshape(-1,1)
y_procesada=y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo=LinearRegression()

# %%
modelo.fit(x_procesada,y_procesada)
# Out:
# LinearRegression()

# %%
modelo.score(x_procesada,y_procesada)
# Out:
# 1.0

# %%
modelo.predict([[564]])
# Out:
# array([[568.70555556]])
